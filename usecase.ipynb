# %%
from transcribe import WhisperTranscriber

# %%
audio_path = "audios/freesound_community-self-destruct-sequence-31505.mp3"

transcriber = WhisperTranscriber()
transcriber.transcribe(audio_path)
# Out:
# Transcription completed!
# Saved to audios/freesound_community-self-destruct-sequence-31505_transcribed.txt

# %%
# install whisper: pip install git+https://github.com/openai/whisper.git
# install ffmpeg (use brew on mac OS: brew install ffmpeg)
# !whisper "curso01.mp3" --model medium (command line usage)
